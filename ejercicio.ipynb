# %% [markdown]
# 4. Genera un cajero automático
# Dado un saldo inicial permite DEPOSITAR, RETIRAR o CONSULTAR SALDO.
# El retiro no debe permitir montos mayores al saldo disponible

# %%
# Cajero  Atumatico

name = input("Introduzca su nombre")

saldo = 1500


print(" Bienvenido al cajero")

while True:
    print("""1. Depositar
             2. Retirar
             3. Consultar
             4. Salir
            """)
    
    seleccion = int(input(" Por favor seleccione una opcion"))

    if seleccion == 1 :
        
        deposito = input(" Cuanto dinero va a ingresar a la cuenta")

        if deposito.isdigit:
            deposito = float(deposito)
            while deposito > 0:
                deposito = float(deposito)
                saldo += deposito
                print(f'Su nuevo saldo es de : {saldo}')
                
                opcion = input("Realizara un nuevo deposito ? si o no")
                if opcion == 'si':
                    deposito = float(input(" Ingrese el deposito :"))
                else:
                    break
                


        print("Opcion no valida")
    
    elif seleccion == 2 :
        print(f"Su saldo actual es de : {saldo}")
        cantidad_retirar = input("Cuanto dinero desea retirar")

        if cantidad_retirar.isdigit:
            cantidad_retirar = float(cantidad_retirar)
            if cantidad_retirar > 0:
                if cantidad_retirar < saldo: 
                    saldo -= cantidad_retirar
                    print(f"El nuevo saldo es de {saldo}")
                else:
                    print("Saldo insuficiente")
            else:
                print("La cantidad a retirar debe ser mayor a 0")

                

        else:
            print("Esto no es un digito")

            
    elif seleccion == 3:
        print(f"Su saldo actual es de {saldo}")
    elif seleccion == 4:
        print("hasta luego")

    else:
        print("Opcion invalida")
        break
# Out:
#  Bienvenido al cajero
# 1. Depositar
#              2. Retirar
#              3. Consultar
#              4. Salir
#
# Su saldo actual es de : 1500
# Saldo insuficiente
# 1. Depositar
#              2. Retirar
#              3. Consultar
#              4. Salir
#
# Su saldo actual es de : 1500
# El nuevo saldo es de 100.0
# 1. Depositar
#              2. Retirar
#              3. Consultar
#              4. Salir
#
# Su saldo actual es de 100.0
# 1. Depositar
#              2. Retirar
#              3. Consultar
#              4. Salir
#
# Opcion invalida
# 1. Depositar
#              2. Retirar
#              3. Consultar
#              4. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 17
#      10 while True:
#      11     print("""1. Depositar
#      12              2. Retirar
#      13              3. Consultar
#      14              4. Salir
# ...
