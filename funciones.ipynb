# %% [markdown]
# Las funciones son pequenios bloque de código los cuales pueden ser reutilizados en el código las veces que queramos
# Existen las funciones built-in, que son funciones que ya vienen definidas en Python y que podemos utilizar directamente sin necesidad de definirlas nosotros mismos. Algunos ejemplos de funciones built-in son: print(), len(), type(), entre otras.
# Las otras funciones las podemo hacer nostros mismos

# %%
# Algunas funciones built-in son :

print("Hola, mundo!")

# Que pasa si hago que una funcion solo de return
def saludar():
    return

saludar()



input()
# Out:
# Hola, mundo!
